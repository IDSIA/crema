# %%
import os
import socket
import subprocess
import pandas as pd
import io
from contextlib import redirect_stdout
import itertools
import warnings
from datetime import datetime
import time
import timeout_decorator
import numpy as np
import matplotlib.pyplot as plt

# %%
def islocal(): return socket.gethostname()=="rc-idsia-macBook.local"
def isserver(): return socket.gethostname()=="ec6120930b2d"
def strdate(): return datetime.today().strftime('%Y-%m-%d-%H-%M-%S')

# %%
if islocal():
    prj_path = "/Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA"
    os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/openjdk-12.0.1.jdk/Contents/Home"
elif isserver():
    prj_path="/home/rcabanas/work_java_crema/crema/CreMA"
else:
    warnings.warn("Unknown server, set prj_path variable manually.")
os.chdir(prj_path)
# !pwd
# Out:
# /home/rcabanas/work_java_crema/crema/CreMA

# %%
exp_folder = f"{prj_path}/papers/pgm20/experiments/"
log_folder = f"{exp_folder}/logs/"
res_folder = f"{exp_folder}/results/"
jarfile=f"{prj_path}/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar"

# %%
# !mvn install:install-file -Dfile=./external/lpsolve55j.jar -DgroupId=net.sf.lpsolve -DartifactId=lp_solve -Dversion=5.5.2 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/lpsolve55j.jar to /home/rcabanas/.m2/repository/net/sf/lpsolve/lp_solve/5.5.2/lp_solve-5.5.2.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.605 s
# [INFO] Finished at: 2020-04-22T09:02:33Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn install:install-file -Dfile=./external/polco.jar -DgroupId=ch.javasoft.polco -DartifactId=polco -Dversion=4.7.1 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/polco.jar to /home/rcabanas/.m2/repository/ch/javasoft/polco/polco/4.7.1/polco-4.7.1.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.600 s
# [INFO] Finished at: 2020-04-22T09:02:35Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn clean compile assembly:single
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ CreMA ---
# [INFO] Deleting /home/rcabanas/work_java_crema/crema/CreMA/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ CreMA ---
# [WARNING] Using platform encoding (UTF-8 actually) to copy filtered resources, i.e. build is platform dependent!
# [INFO] skip non existing resourceDirectory /home/rcabanas/work_java_crema/crema/CreMA/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ CreMA ---
# [INFO] Changes detected - recompiling the module!
# [WARNING] File encoding has not been set, using platform encoding UTF-8, i.e. build is platform dependent!
# [INFO] Compiling 226 source files to /home/rcabanas/work_java_crema/crema/CreMA/target/classes
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/factor/bayesian/BayesianFactor.java: Some input files use or override a deprecated API.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/factor/bayesian/BayesianFactor.java: Recompile with -Xlint:deprecation for details.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Some input files use unchecked or unsafe operations.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Recompile with -Xlint:unchecked for details.
# [INFO]
# [INFO] --- maven-assembly-plugin:2.2-beta-5:single (default-cli) @ CreMA ---
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] Building jar: /home/rcabanas/work_java_crema/crema/CreMA/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  8.419 s
# [INFO] Finished at: 2020-04-22T09:02:44Z
# [INFO] ------------------------------------------------------------------------

# %%
#@timeout_decorator.timeout(30*60)
def run_java(jarfile, javafile):
    cmd=f"java -cp {jarfile} {javafile}"
    result =subprocess.run(cmd, universal_newlines = True, shell=True,stdout = subprocess.PIPE)
    print(result.stdout)
    return result

# ChainNonMarkovian 6 5 1 -1 0 CCALP 1234
def run_chain(model, N, exovarsize, target, obsvar, dovar, method, seed):
    javafile = f"{exp_folder}/RunExperiments.java {model} {N} {exovarsize} {target} {obsvar} {dovar} {method} {seed}"  
    try:
        result = run_java(jarfile, javafile)
        output = [float(x) for x in result.stdout.splitlines()[-1].split(",")]
    except:
        output = [float("inf"),float("inf"),float("nan")]
        
    return output

def run_chain_markovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=-1, method="CVE", seed=1234):
    return run_chain("ChainMarkovian", N, exovarsize, target or N-1, obsvar, dovar, method, seed)

def run_chain_nonmarkovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=-1, method="CVE", seed=1234):
    return run_chain("ChainNonMarkovian", N, exovarsize, target or N-1, obsvar, dovar, method, seed)

# %%
run_chain_markovian(N=5, dovar=0, method="CCVE")
# Out:
# ChainMarkovian
#    N=5 exovarsize=6 target=4 obsvar=-1 dovar=0 method=CCVE seed=1234
# =================================================================
# Running experiments...
# set timeout 600 s.
# Warm-up #0 in 670.432 ms.
# set timeout 600 s.
# Warm-up #1 in 210.872 ms.
# set timeout 600 s.
# Warm-up #2 in 202.608 ms.
# set timeout 300 s.
# Measurement #0 in 198.018 ms. size=0.0
# set timeout 300 s.
# Measurement #1 in 148.807 ms. size=0.0
# set timeout 300 s.
# Measurement #2 in 153.172 ms. size=0.0
# set timeout 300 s.
# Measurement #3 in 138.32 ms. size=0.0
# set timeout 300 s.
# Measurement #4 in 138.023 ms. size=0.0
# set timeout 300 s.
# Measurement #5 in 150.002 ms. size=0.0
# set timeout 300 s.
# Measurement #6 in 118.144 ms. size=0.0
# set timeout 300 s.
# Measurement #7 in 132.344 ms. size=0.0
# set timeout 300 s.
# Measurement #8 in 129.158 ms. size=0.0
# set timeout 300 s.
# Measurement #9 in 114.78 ms. size=0.0
# 142.0768,24.2594,0.0
# [142.0768, 24.2594, 0.0]

# %%
run_chain_nonmarkovian(N=3, exovarsize=6, method="CCALP", seed=543)
run_chain_nonmarkovian(N=3, exovarsize=6, method="CCALPeps", seed=543)
# Out:
# ChainNonMarkovian
#    N=3 exovarsize=6 target=2 obsvar=-1 dovar=-1 method=CCALP seed=543
# =================================================================
# Running experiments...
# set timeout 600 s.
# Warm-up #0 in 414.341 ms.
# set timeout 600 s.
# Warm-up #1 in 158.736 ms.
# set timeout 600 s.
# Warm-up #2 in 109.378 ms.
# set timeout 300 s.
# Measurement #0 in 137.046 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #1 in 134.445 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #2 in 132.377 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #3 in 123.549 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #4 in 124.632 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #5 in 121.921 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #6 in 123.569 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #7 in 121.2 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #8 in 121.494 ms. size=5.551115123125783E-17
# set timeout 300 s.
# Measurement #9 in 122.957 ms. size=5.551115123125783E-17
# 126.319,124.2613,5.551115123125783E-17
#
#
# ChainNonMarkovian
#    N=3 exovarsize=6 target=2 obsvar=-1 dovar=-1 method=CCALPeps seed=543
# =================================================================
# Running experiments...
# set timeout 600 s.
# Warm-up #0 in 574.658 ms.
# set timeout 600 s.
# Warm-up #1 in 293.498 ms.
# set timeout 600 s.
# Warm-up #2 in 296.301 ms.
# set timeout 300 s.
# Measurement #0 in 280.36 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #1 in 286.617 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #2 in 291.986 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #3 in 277.293 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #4 in 281.646 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #5 in 277.575 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #6 in 231.562 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #7 in 245.805 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #8 in 210.934 ms. size=2.703005213600118E-6
# set timeout 300 s.
# Measurement #9 in 220.692 ms. size=2.703005213600118E-6
# 260.447,258.5976,2.703005213600118E-6
# [260.447, 258.5976, 2.703005213600118e-06]

# %%
def run_experiments(f, args, outkeys=("time", "query_time", "size")):

    result = pd.DataFrame(columns=list(args.keys())+list(outkeys))
    log_file = f"{log_folder}{strdate()}_{f.__name__}.txt"

    for v in itertools.product(*list(args.values())):
        argsv = dict(zip(list(args.keys()), v))
        strio = io.StringIO()
        with open(log_file, 'a+') as logger:
            with redirect_stdout(strio):
                outvals = f(**argsv)
            logger.write(strio.getvalue())
        result = result.append({**argsv, **dict(zip(list(outkeys), outvals))}, ignore_index=True)
        print(dict(result.iloc[-1]))
    
    return result

# %%
args = {"N":list(range(5,15)), "exovarsize":[6], "dovar":[0], "seed":[1234], "method":["CVE", "CCVE","CCALP", "CCALPeps"]}

# %%
results1 = run_experiments(run_chain_markovian, args)
res_file = f"{res_folder}{strdate()}_chain_markovian.csv"
results1.to_csv(res_file)
results1
# Out:
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 2.1018, 'query_time': 2.0817, 'size': 0.0}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 144.7788, 'query_time': 24.9877, 'size': 0.0}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 245.2279, 'query_time': 242.75410000000002, 'size': 0.0}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 666.7597, 'query_time': 664.5415, 'size': 5.000009998790134e-06}
# {'N': 6, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 2.9505, 'query_time': 2.9307, 'size': 0.0}
# {'N': 6, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 244.0244, 'query_time': 109.7953, 'size': 0.0}
# {'N': 6, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 347.3075, 'query_time': 344.6448, 'size': 0.0}
# {'N': 6, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 927.6030000000001, 'query_time': 924.8543, 'size': 6.00001499895253e-06}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 7.550700000000001, 'query_time': 6.1435, 'size': 0.0}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 605.4981, 'query_time': 475.9362, 'size': 0.0}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 359.7791, 'query_time': 357.1259, 'size': 0.0}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1250.5691, 'query_time': 1247.3328, 'size': 7.000020998687573e-06}
# {'N': 8, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 26.1829, 'query_time': 26.160899999999998, 'size': 0.0}
# {'N': 8, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 3216.2264, 'query_time': 3054.9345000000003, 'size': 0.0}
# {'N': 8, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 439.4419, 'query_time': 436.7638, 'size': 1.1102230246251565e-16}
# {'N': 8, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1502.2359000000001, 'query_time': 1498.9316999999999, 'size': 8.00002799867805e-06}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 131.93869999999998, 'query_time': 131.9075, 'size': 0.0}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 16937.6716, 'query_time': 16753.9817, 'size': 0.0}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 602.152, 'query_time': 599.0521, 'size': 1.1102230246251565e-16}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1712.7096000000001, 'query_time': 1709.6105, 'size': 9.00003599871857e-06}
# {'N': 10, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 734.3792000000001, 'query_time': 734.3491, 'size': 0.0}
# {'N': 10, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 82105.56950000001, 'query_time': 81902.3711, 'size': 0.0}
# {'N': 10, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 602.4857, 'query_time': 599.1904999999999, 'size': 2.2204460492503132e-17}
# {'N': 10, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1994.2718, 'query_time': 1990.9679, 'size': 1.0000044998814683e-05}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 4450.2685, 'query_time': 4450.2203, 'size': 0.0}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 666.3100000000001, 'query_time': 663.1556, 'size': 2.7755575615628914e-17}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 2381.8908, 'query_time': 2378.0863, 'size': 1.1000054998552833e-05}
# {'N': 12, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 32325.9749, 'query_time': 32325.923500000004, 'size': 0.0}
# {'N': 12, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 12, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 733.5081, 'query_time': 730.2948, 'size': 2.220446049250313e-16}
# {'N': 12, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 2720.5038, 'query_time': 2716.2858, 'size': 1.2000065998651887e-05}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': nan, 'query_time': nan, 'size': nan}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 902.7627, 'query_time': 898.8198, 'size': 1.1102230246251565e-16}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 3124.5364, 'query_time': 3119.9961, 'size': 1.3000077998226444e-05}
# {'N': 14, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': nan, 'query_time': nan, 'size': nan}
# {'N': 14, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 14, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 960.1987000000001, 'query_time': 956.0791999999999, 'size': 0.0}
# {'N': 14, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 3176.4165000000003, 'query_time': 3171.7725, 'size': 1.4000090998345095e-05}
#      N exovarsize dovar  seed    method        time  query_time          size
# 0    5          6     0  1234       CVE      2.1018      2.0817  0.000000e+00
# 1    5          6     0  1234      CCVE    144.7788     24.9877  0.000000e+00
# 2    5          6     0  1234     CCALP    245.2279    242.7541  0.000000e+00
# 3    5          6     0  1234  CCALPeps    666.7597    664.5415  5.000010e-06
# 4    6          6     0  1234       CVE      2.9505      2.9307  0.000000e+00
# 5    6          6     0  1234      CCVE    244.0244    109.7953  0.000000e+00
# 6    6          6     0  1234     CCALP    347.3075    344.6448  0.000000e+00
# 7    6          6     0  1234  CCALPeps    927.6030    924.8543  6.000015e-06
# 8    7          6     0  1234       CVE      7.5507      6.1435  0.000000e+00
# 9    7          6     0  1234      CCVE    605.4981    475.9362  0.000000e+00
# 10   7          6     0  1234     CCALP    359.7791    357.1259  0.000000e+00
# 11   7          6     0  1234  CCALPeps   1250.5691   1247.3328  7.000021e-06
# 12   8          6     0  1234       CVE     26.1829     26.1609  0.000000e+00
# 13   8          6     0  1234      CCVE   3216.2264   3054.9345  0.000000e+00
# 14   8          6     0  1234     CCALP    439.4419    436.7638  1.110223e-16
# 15   8          6     0  1234  CCALPeps   1502.2359   1498.9317  8.000028e-06
# 16   9          6     0  1234       CVE    131.9387    131.9075  0.000000e+00
# 17   9          6     0  1234      CCVE  16937.6716  16753.9817  0.000000e+00
# 18   9          6     0  1234     CCALP    602.1520    599.0521  1.110223e-16
# 19   9          6     0  1234  CCALPeps   1712.7096   1709.6105  9.000036e-06
# 20  10          6     0  1234       CVE    734.3792    734.3491  0.000000e+00
# 21  10          6     0  1234      CCVE  82105.5695  81902.3711  0.000000e+00
# 22  10          6     0  1234     CCALP    602.4857    599.1905  2.220446e-17
# 23  10          6     0  1234  CCALPeps   1994.2718   1990.9679  1.000004e-05
# 24  11          6     0  1234       CVE   4450.2685   4450.2203  0.000000e+00
# 25  11          6     0  1234      CCVE         inf         inf           NaN
# 26  11          6     0  1234     CCALP    666.3100    663.1556  2.775558e-17
# 27  11          6     0  1234  CCALPeps   2381.8908   2378.0863  1.100005e-05
# 28  12          6     0  1234       CVE  32325.9749  32325.9235  0.000000e+00
# 29  12          6     0  1234      CCVE         inf         inf           NaN
# 30  12          6     0  1234     CCALP    733.5081    730.2948  2.220446e-16
# 31  12          6     0  1234  CCALPeps   2720.5038   2716.2858  1.200007e-05
# 32  13          6     0  1234       CVE         NaN         NaN           NaN
# 33  13          6     0  1234      CCVE         inf         inf           NaN
# 34  13          6     0  1234     CCALP    902.7627    898.8198  1.110223e-16
# 35  13          6     0  1234  CCALPeps   3124.5364   3119.9961  1.300008e-05
# 36  14          6     0  1234       CVE         NaN         NaN           NaN
# 37  14          6     0  1234      CCVE         inf         inf           NaN
# 38  14          6     0  1234     CCALP    960.1987    956.0792  0.000000e+00
# 39  14          6     0  1234  CCALPeps   3176.4165   3171.7725  1.400009e-05

# %%
args = {"N":list(range(5,30,2)), "exovarsize":[6], "dovar":[0], "seed":[1234], "method":["CVE", "CCVE","CCALP", "CCALPeps"]}
results2 = run_experiments(run_chain_nonmarkovian, args)
res_file = f"{res_folder}{strdate()}_chain_nonmarkovian.csv"
results2.to_csv(res_file)
results2
# Out:
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 1.5131000000000001, 'query_time': 1.4929999999999999, 'size': 0.0}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 80.23440000000001, 'query_time': 7.7152, 'size': 0.0}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 241.88160000000002, 'query_time': 239.42350000000002, 'size': 1.1102230246251565e-16}
# {'N': 5, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 543.8916999999999, 'query_time': 541.5652, 'size': 4.751537370650816e-06}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 2.4042000000000003, 'query_time': 2.3845, 'size': 0.0}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 117.3578, 'query_time': 21.2225, 'size': 0.0}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 348.9792, 'query_time': 346.4026, 'size': 1.9428902930940238e-17}
# {'N': 7, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 960.5523000000001, 'query_time': 957.3358000000001, 'size': 6.726188542693912e-06}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 3.8145, 'query_time': 3.7950000000000004, 'size': 0.0}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 190.4811, 'query_time': 87.398, 'size': 0.0}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 487.7234, 'query_time': 484.9949, 'size': 0.0}
# {'N': 9, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1460.1361000000002, 'query_time': 1457.2445, 'size': 8.985866253452546e-06}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 8.5275, 'query_time': 8.5048, 'size': 0.0}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 464.86710000000005, 'query_time': 357.7957, 'size': 0.0}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 671.8605, 'query_time': 668.5594, 'size': 5.551115123125783e-17}
# {'N': 11, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 1849.502, 'query_time': 1846.145, 'size': 1.099793825077855e-05}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 30.1575, 'query_time': 30.1361, 'size': 0.0}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 3242.7228999999998, 'query_time': 3104.4216, 'size': 0.0010630919519999393}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 838.4134, 'query_time': 834.8237999999999, 'size': 0.00011825193369601195}
# {'N': 13, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 2829.1234, 'query_time': 2825.451, 'size': 0.00013482031785693182}
# {'N': 15, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 144.9435, 'query_time': 144.9187, 'size': 0.0}
# {'N': 15, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 16925.3669, 'query_time': 16771.6981, 'size': 4.543128000467078e-07}
# {'N': 15, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 975.8552999999999, 'query_time': 972.1339, 'size': 2.3048063990671608e-07}
# {'N': 15, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 3223.4510999999998, 'query_time': 3219.7044, 'size': 1.4769628138910918e-05}
# {'N': 17, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 827.2275999999999, 'query_time': 827.1972, 'size': 0.0}
# {'N': 17, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 79131.9406, 'query_time': 78971.3244, 'size': 0.0}
# {'N': 17, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 1183.8219000000001, 'query_time': 1179.6349, 'size': 0.0}
# {'N': 17, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 3676.7805, 'query_time': 3672.7414, 'size': 1.7000123332838733e-05}
# {'N': 19, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 5134.6833, 'query_time': 5134.6388, 'size': 0.0}
# {'N': 19, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 19, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 1436.8572, 'query_time': 1432.1341, 'size': 0.0}
# {'N': 19, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 4457.5943, 'query_time': 4452.9779, 'size': 1.9000166424998356e-05}
# {'N': 21, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 31314.4778, 'query_time': 31314.4375, 'size': 0.0}
# {'N': 21, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan}
# {'N': 21, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 1742.0453999999997, 'query_time': 1736.2815999999998, 'size': 2.498001805406602e-16}

# %%
methods = np.unique(results1["method"].to_numpy())

# %%
results1.filter(items=["N","method","time"])

# %%
fig=plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')

N = np.unique(results1["N"].to_numpy())

for m in methods:
    #if m not in ["CCVE"]:
        data = results1.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
        plt.plot(N, data, marker='o', label=m)
        plt.legend()
        #ax1.set_yscale('log')
        
plt.ylabel("time (ms)")
plt.xlabel("Number of endogenous variables")

plt.title("Chain (Makovian case)")

plt.show()

# %%
fig=plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')

N = np.unique(results2["N"].to_numpy())


for m in methods:
    #if m not in ["CCVE"]:

        data = results2.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
        plt.plot(N, data, marker='o', label=m)

        #data = results2.query(f"method=='{m}'").filter(items=["query_time"]).to_numpy()
        #ax2.plot(N, data, marker='o', label=m)
        #ax1.set_yscale('log')

        plt.legend()   
        
plt.ylabel("time (ms)")
plt.title("Chain (Non-Makovian case)")
plt.xlabel("Number of endogenous variables")

fig.show()
