# %%
import os
import socket
import subprocess
import pandas as pd
import io
from contextlib import redirect_stdout
import itertools
import warnings
from datetime import datetime
import time
import timeout_decorator

# %%
def islocal(): return socket.gethostname()=="rc-idsia-macBook.local"
def isserver(): return socket.gethostname()=="ec6120930b2d"
def strdate(): return datetime.today().strftime('%Y-%m-%d-%H-%M-%S')

# %%
if islocal():
    prj_path = "/Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA"
    os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/openjdk-12.0.1.jdk/Contents/Home"
elif isserver():
    prj_path="/home/rcabanas/work_java_crema/crema/CreMA"
else:
    warnings.warn("Unknown server, set prj_path variable manually.")
os.chdir(prj_path)
# !pwd
# Out:
# /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA

# %%
exp_folder = f"{prj_path}/papers/pgm20/experiments/"
log_folder = f"{exp_folder}/logs/"
res_folder = f"{exp_folder}/results/"
jarfile=f"{prj_path}/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar"

# %%
# !mvn install:install-file -Dfile=./external/lpsolve55j.jar -DgroupId=net.sf.lpsolve -DartifactId=lp_solve -Dversion=5.5.2 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/lpsolve55j.jar to /home/rcabanas/.m2/repository/net/sf/lpsolve/lp_solve/5.5.2/lp_solve-5.5.2.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.613 s
# [INFO] Finished at: 2020-04-17T09:51:59Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn install:install-file -Dfile=./external/polco.jar -DgroupId=ch.javasoft.polco -DartifactId=polco -Dversion=4.7.1 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/polco.jar to /home/rcabanas/.m2/repository/ch/javasoft/polco/polco/4.7.1/polco-4.7.1.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.617 s
# [INFO] Finished at: 2020-04-17T09:52:01Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn clean compile assembly:single
# Out:
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ CreMA ---
# [INFO] Deleting /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ CreMA ---
# [WARNING] Using platform encoding (US-ASCII actually) to copy filtered resources, i.e. build is platform dependent!
# [INFO] skip non existing resourceDirectory /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ CreMA ---
# [INFO] Changes detected - recompiling the module!
# [WARNING] File encoding has not been set, using platform encoding US-ASCII, i.e. build is platform dependent!
# [INFO] Compiling 225 source files to /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/target/classes
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[4,35] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[4,36] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[4,37] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[281,54] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[281,55] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[281,56] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[790,73] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[790,74] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[790,75] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1391,81] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1391,82] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1391,83] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1392,91] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1392,92] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1392,93] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1501,26] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1501,27] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1501,28] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1503,59] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1503,60] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1503,61] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1556,46] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1556,47] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[1556,48] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2135,76] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2135,77] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2135,78] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2231,80] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2231,81] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2231,82] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2232,36] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2232,37] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[2232,38] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3441,31] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3441,32] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3441,33] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3537,31] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3537,32] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3537,33] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3601,31] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3601,32] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3601,33] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3850,57] unmappable character (0xEF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3850,58] unmappable character (0xBF) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/generator/BNGenerator.java:[3850,59] unmappable character (0xBD) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/specialized/StructuralCausalModel.java:[29,24] unmappable character (0xC3) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/specialized/StructuralCausalModel.java:[29,25] unmappable character (0xB1) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp2/Move.java:[26,25] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp2/Move.java:[26,26] unmappable character (0x88) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp2/Move.java:[26,27] unmappable character (0x8F) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp/Move.java:[26,25] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp/Move.java:[26,26] unmappable character (0x88) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/approxlp/Move.java:[26,27] unmappable character (0x8F) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[9,32] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[9,33] unmappable character (0x88) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[9,34] unmappable character (0x92) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,21] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,22] unmappable character (0x86) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,23] unmappable character (0x90) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,52] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,53] unmappable character (0x89) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,54] unmappable character (0xA4) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,58] unmappable character (0xE2) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,59] unmappable character (0x89) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/CredoArrays.java:[10,60] unmappable character (0xA4) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/causality/CausalInference.java:[13,24] unmappable character (0xC3) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/inference/causality/CausalInference.java:[13,25] unmappable character (0xB1) for encoding US-ASCII
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/factor/credal/vertex/VertexFactor.java: Some input files use or override a deprecated API.
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/factor/credal/vertex/VertexFactor.java: Recompile with -Xlint:deprecation for details.
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Some input files use unchecked or unsafe operations.
# [WARNING] /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Recompile with -Xlint:unchecked for details.
# [INFO]
# [INFO] --- maven-assembly-plugin:2.2-beta-5:single (default-cli) @ CreMA ---
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] Building jar: /Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  12.319 s
# [INFO] Finished at: 2020-04-20T12:47:13+02:00
# [INFO] ------------------------------------------------------------------------

# %%
@timeout_decorator.timeout(20*60)
def run_java(jarfile, javafile):
    cmd=f"java -cp {jarfile} {javafile}"
    result =subprocess.run(cmd, universal_newlines = True, shell=True,stdout = subprocess.PIPE)
    print(result.stdout)
    return result

# ChainNonMarkovian 6 5 1 -1 0 CCALP 1234
def run_chain(model, N, exovarsize, target, obsvar, dovar, method, seed):
    javafile = f"{exp_folder}/RunExperiments.java {model} {N} {exovarsize} {target} {obsvar} {dovar} {method} {seed}"  
    try:
        result = run_java(jarfile, javafile)
        output = [float(x) for x in result.stdout.splitlines()[-1].split(",")]
    except:
        output = [float("inf"),float("inf"),float("nan")]
        
    return output

def run_chain_markovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=-1, method="CVE", seed=1234):
    return run_chain("ChainMarkovian", N, exovarsize, target or N-1, obsvar, dovar, method, seed)

def run_chain_nonmarkovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=-1, method="CVE", seed=1234):
    return run_chain("ChainNonMarkovian", N, exovarsize, target or N-1, obsvar, dovar, method, seed)

# %%
run_chain_markovian(N=5, dovar=0, method="CCVE")
# Out:
# ChainMarkovian
#    N=5 exovarsize=6 target=4 obsvar=-1 dovar=0 method=CCVE seed=1234
# =================================================================
# Running experiments...
# Warm-up #0 in 948.457 ms.
# Warm-up #1 in 267.133 ms.
# Warm-up #2 in 222.551 ms.
# Measurement #0 in 187.735 ms. size=53.201
# Measurement #1 in 155.724 ms. size=40.79
# Measurement #2 in 152.846 ms. size=44.403
# Measurement #3 in 156.34 ms. size=42.222
# Measurement #4 in 135.211 ms. size=39.274
# Measurement #5 in 149.979 ms. size=51.104
# Measurement #6 in 156.34 ms. size=46.171
# Measurement #7 in 113.278 ms. size=33.265
# Measurement #8 in 112.85 ms. size=27.372
# Measurement #9 in 123.645 ms. size=27.345
# 40.5147,0.0,0.0
# [40.5147, 0.0, 0.0]

# %%
run_chain_nonmarkovian(N=3, exovarsize=6, method="CCVE", seed=543)
# Out:
# ChainNonMarkovian
#    N=3 exovarsize=6 target=2 obsvar=-1 dovar=-1 method=CCVE seed=543
# =================================================================
# Running experiments...
# Warm-up #0 in 545.608 ms.
# Warm-up #1 in 86.822 ms.
# Warm-up #2 in 87.323 ms.
# Measurement #0 in 75.468 ms. size=6.535
# Measurement #1 in 68.301 ms. size=5.495
# Measurement #2 in 64.459 ms. size=5.256
# Measurement #3 in 59.571 ms. size=5.865
# Measurement #4 in 73.941 ms. size=3.616
# Measurement #5 in 66.745 ms. size=3.136
# Measurement #6 in 55.813 ms. size=2.447
# Measurement #7 in 51.772 ms. size=3.195
# Measurement #8 in 45.301 ms. size=2.633
# Measurement #9 in 48.714 ms. size=1.82
# 61.008500000000005,3.9997999999999996,0.0
# [61.008500000000005, 3.9997999999999996, 0.0]

# %%
def run_experiments(f, args, outkeys=("time", "query_time", "size")):

    result = pd.DataFrame(columns=list(args.keys())+list(outkeys))
    log_file = f"{log_folder}{strdate()}_{f.__name__}.txt"

    for v in itertools.product(*list(args.values())):
        argsv = dict(zip(list(args.keys()), v))
        strio = io.StringIO()
        with open(log_file, 'a+') as logger:
            with redirect_stdout(strio):
                outvals = f(**argsv)
            logger.write(strio.getvalue())
        result = result.append({**argsv, **dict(zip(list(outkeys), outvals))}, ignore_index=True)
        print(dict(result.iloc[-1]))
    
    return result

# %%
args = {"N":list(range(2,5)), "exovarsize":[6], "dovar":[0], "seed":[1234], "method":["CVE", "CCVE","CCALP", "CCALPeps"]}

# %%
results1 = run_experiments(run_chain_markovian, args)
res_file = f"{res_folder}{strdate()}_chain_markovian.csv"
results1.to_csv(res_file)
results1
# Out:
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 1.1542999999999999, 'query_time': 1.1455, 'size': 0.0}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 62.6865, 'query_time': 2.2727, 'size': 0.0}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 60.420399999999994, 'query_time': 58.7192, 'size': 0.0}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 136.7846, 'query_time': 134.7422, 'size': 2.147682583775179e-06}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 2.4982, 'query_time': 2.4894000000000003, 'size': 0.0}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 90.46079999999999, 'query_time': 5.3119, 'size': 0.0}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 102.82239999999999, 'query_time': 100.4136, 'size': 1.1102230246251565e-16}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 316.69259999999997, 'query_time': 314.5596, 'size': 3.1032649636997255e-06}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 2.702, 'query_time': 2.6927, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 101.8699, 'query_time': 15.543000000000001, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 131.1028, 'query_time': 128.07999999999998, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 650.2850999999999, 'query_time': 647.1354, 'size': 3.0832347163389785e-06}
#     N exovarsize dovar  seed    method      time  query_time          size
# 0   2          6     0  1234       CVE    1.1543      1.1455  0.000000e+00
# 1   2          6     0  1234      CCVE   62.6865      2.2727  0.000000e+00
# 2   2          6     0  1234     CCALP   60.4204     58.7192  0.000000e+00
# 3   2          6     0  1234  CCALPeps  136.7846    134.7422  2.147683e-06
# 4   3          6     0  1234       CVE    2.4982      2.4894  0.000000e+00
# 5   3          6     0  1234      CCVE   90.4608      5.3119  0.000000e+00
# 6   3          6     0  1234     CCALP  102.8224    100.4136  1.110223e-16
# 7   3          6     0  1234  CCALPeps  316.6926    314.5596  3.103265e-06
# 8   4          6     0  1234       CVE    2.7020      2.6927  0.000000e+00
# 9   4          6     0  1234      CCVE  101.8699     15.5430  0.000000e+00
# 10  4          6     0  1234     CCALP  131.1028    128.0800  0.000000e+00
# 11  4          6     0  1234  CCALPeps  650.2851    647.1354  3.083235e-06

# %%
results2 = run_experiments(run_chain_nonmarkovian, args)
res_file = f"{res_folder}{strdate()}_chain_nonmarkovian.csv"
results2.to_csv(res_file)
results2
# Out:
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 1.4381, 'query_time': 1.4288, 'size': 0.0}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 37.175799999999995, 'query_time': 1.8123, 'size': 0.0}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 58.8304, 'query_time': 57.497699999999995, 'size': 2.7755575615628914e-17}
# {'N': 2, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 159.0303, 'query_time': 157.6934, 'size': 2.5676038465649587e-06}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 1.1611, 'query_time': 1.1521000000000001, 'size': 0.0}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 70.1768, 'query_time': 4.1692, 'size': 0.0}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 160.2235, 'query_time': 157.4494, 'size': 0.0}
# {'N': 3, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 311.6313, 'query_time': 309.75030000000004, 'size': 3.22995222997724e-06}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CVE', 'time': 1.6995, 'query_time': 1.6895, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCVE', 'time': 72.0232, 'query_time': 4.9933, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALP', 'time': 155.5711, 'query_time': 152.27870000000001, 'size': 0.0}
# {'N': 4, 'exovarsize': 6, 'dovar': 0, 'seed': 1234, 'method': 'CCALPeps', 'time': 581.3507000000001, 'query_time': 579.1928, 'size': 3.2312098494372e-06}
#     N exovarsize dovar  seed    method      time  query_time          size
# 0   2          6     0  1234       CVE    1.4381      1.4288  0.000000e+00
# 1   2          6     0  1234      CCVE   37.1758      1.8123  0.000000e+00
# 2   2          6     0  1234     CCALP   58.8304     57.4977  2.775558e-17
# 3   2          6     0  1234  CCALPeps  159.0303    157.6934  2.567604e-06
# 4   3          6     0  1234       CVE    1.1611      1.1521  0.000000e+00
# 5   3          6     0  1234      CCVE   70.1768      4.1692  0.000000e+00
# 6   3          6     0  1234     CCALP  160.2235    157.4494  0.000000e+00
# 7   3          6     0  1234  CCALPeps  311.6313    309.7503  3.229952e-06
# 8   4          6     0  1234       CVE    1.6995      1.6895  0.000000e+00
# 9   4          6     0  1234      CCVE   72.0232      4.9933  0.000000e+00
# 10  4          6     0  1234     CCALP  155.5711    152.2787  0.000000e+00
# 11  4          6     0  1234  CCALPeps  581.3507    579.1928  3.231210e-06

# %%
N = np.unique(results1["N"].to_numpy())
methods = np.unique(results1["method"].to_numpy())

# %%
results1.filter(items=["N","method","time"])
# Out:
#     N    method      time
# 0   2       CVE    1.1543
# 1   2      CCVE   62.6865
# 2   2     CCALP   60.4204
# 3   2  CCALPeps  136.7846
# 4   3       CVE    2.4982
# 5   3      CCVE   90.4608
# 6   3     CCALP  102.8224
# 7   3  CCALPeps  316.6926
# 8   4       CVE    2.7020
# 9   4      CCVE  101.8699
# 10  4     CCALP  131.1028
# 11  4  CCALPeps  650.2851

# %%
data = results1.query("method=='CVE'").filter(items=["N","time"]).to_numpy()

# %%
import matplotlib.pyplot as plt

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

for m in methods:
    data = results1.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
    ax1.plot(N, data, marker='o', label=m)
    
    data = results1.query(f"method=='{m}'").filter(items=["query_time"]).to_numpy()
    ax2.plot(N, data, marker='o', label=m)
    
    ax1.legend()   
    ax2.legend()    

fig.show()
# Out:
# /Users/rcabanas/.pyenv/versions/3.6.9/lib/python3.6/site-packages/ipykernel_launcher.py:12: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if sys.path[0] == '':

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

for m in methods:
    data = results2.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
    ax1.plot(N, data, marker='o', label=m)
    
    data = results2.query(f"method=='{m}'").filter(items=["query_time"]).to_numpy()
    ax2.plot(N, data, marker='o', label=m)
    
    ax1.legend()   
    ax2.legend()    

fig.show()
# Out:
# /Users/rcabanas/.pyenv/versions/3.6.9/lib/python3.6/site-packages/ipykernel_launcher.py:13: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   del sys.path[0]
