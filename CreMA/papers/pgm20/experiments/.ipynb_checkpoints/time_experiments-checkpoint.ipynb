# %%
import os
import socket
import subprocess
import pandas as pd
import io
from contextlib import redirect_stdout
import itertools
import warnings
from datetime import datetime
import time
import timeout_decorator
import numpy as np
import matplotlib.pyplot as plt

# %%
def islocal(): return socket.gethostname()=="rc-idsia-macBook.local"
def isserver(): return socket.gethostname()=="ec6120930b2d"
def strdate(): return datetime.today().strftime('%Y-%m-%d-%H-%M-%S')

# %%
if islocal():
    prj_path = "/Users/rcabanas/GoogleDrive/IDSIA/causality/dev/crema/CreMA"
    os.environ['JAVA_HOME'] = "/Library/Java/JavaVirtualMachines/openjdk-12.0.1.jdk/Contents/Home"
elif isserver():
    prj_path="/home/rcabanas/work_java_crema/crema/CreMA"
else:
    warnings.warn("Unknown server, set prj_path variable manually.")
os.chdir(prj_path)
# !pwd
# Out:
# /home/rcabanas/work_java_crema/crema/CreMA

# %%
exp_folder = f"{prj_path}/papers/pgm20/experiments/"
log_folder = f"{exp_folder}/logs/"
res_folder = f"{exp_folder}/results/"
jarfile=f"{prj_path}/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar"

# %%
# !mvn install:install-file -Dfile=./external/lpsolve55j.jar -DgroupId=net.sf.lpsolve -DartifactId=lp_solve -Dversion=5.5.2 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/lpsolve55j.jar to /home/rcabanas/.m2/repository/net/sf/lpsolve/lp_solve/5.5.2/lp_solve-5.5.2.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.610 s
# [INFO] Finished at: 2020-04-23T06:37:57Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn install:install-file -Dfile=./external/polco.jar -DgroupId=ch.javasoft.polco -DartifactId=polco -Dversion=4.7.1 -Dpackaging=jar
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-install-plugin:2.4:install-file (default-cli) @ CreMA ---
# [INFO] Installing /home/rcabanas/work_java_crema/crema/CreMA/external/polco.jar to /home/rcabanas/.m2/repository/ch/javasoft/polco/polco/4.7.1/polco-4.7.1.jar
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  0.622 s
# [INFO] Finished at: 2020-04-23T06:37:59Z
# [INFO] ------------------------------------------------------------------------

# %%
# !mvn clean compile assembly:single
# Out:
# WARNING: An illegal reflective access operation has occurred
# WARNING: Illegal reflective access by com.google.inject.internal.cglib.core.$ReflectUtils$1 (file:/usr/share/maven/lib/guice.jar) to method java.lang.ClassLoader.defineClass(java.lang.String,byte[],int,int,java.security.ProtectionDomain)
# WARNING: Please consider reporting this to the maintainers of com.google.inject.internal.cglib.core.$ReflectUtils$1
# WARNING: Use --illegal-access=warn to enable warnings of further illegal reflective access operations
# WARNING: All illegal access operations will be denied in a future release
# [INFO] Scanning for projects...
# [WARNING]
# [WARNING] Some problems were encountered while building the effective model for ch.idsia:CreMA:jar:0.1.1-SNAPSHOT
# [WARNING] 'dependencies.dependency.(groupId:artifactId:type:classifier)' must be unique: org.apache.commons:commons-math3:jar -> duplicate declaration of version 3.6.1 @ line 125, column 15
# [WARNING]
# [WARNING] It is highly recommended to fix these problems because they threaten the stability of your build.
# [WARNING]
# [WARNING] For this reason, future Maven versions might no longer support building such malformed projects.
# [WARNING]
# [INFO]
# [INFO] ---------------------------< ch.idsia:CreMA >---------------------------
# [INFO] Building Credal Model Algorithms 0.1.1-SNAPSHOT
# [INFO] --------------------------------[ jar ]---------------------------------
# [INFO]
# [INFO] --- maven-clean-plugin:2.5:clean (default-clean) @ CreMA ---
# [INFO] Deleting /home/rcabanas/work_java_crema/crema/CreMA/target
# [INFO]
# [INFO] --- maven-resources-plugin:2.6:resources (default-resources) @ CreMA ---
# [WARNING] Using platform encoding (UTF-8 actually) to copy filtered resources, i.e. build is platform dependent!
# [INFO] skip non existing resourceDirectory /home/rcabanas/work_java_crema/crema/CreMA/src/main/resources
# [INFO]
# [INFO] --- maven-compiler-plugin:3.1:compile (default-compile) @ CreMA ---
# [INFO] Changes detected - recompiling the module!
# [WARNING] File encoding has not been set, using platform encoding UTF-8, i.e. build is platform dependent!
# [INFO] Compiling 226 source files to /home/rcabanas/work_java_crema/crema/CreMA/target/classes
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/factor/bayesian/BayesianFactor.java: Some input files use or override a deprecated API.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/factor/bayesian/BayesianFactor.java: Recompile with -Xlint:deprecation for details.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Some input files use unchecked or unsafe operations.
# [WARNING] /home/rcabanas/work_java_crema/crema/CreMA/src/main/java/ch/idsia/crema/model/graphical/GenericSparseModel.java: Recompile with -Xlint:unchecked for details.
# [INFO]
# [INFO] --- maven-assembly-plugin:2.2-beta-5:single (default-cli) @ CreMA ---
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] Building jar: /home/rcabanas/work_java_crema/crema/CreMA/target/CreMA-0.1.1-SNAPSHOT-jar-with-dependencies.jar
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/eclipse.inf already added, skipping
# [INFO] license.html already added, skipping
# [INFO] about.html already added, skipping
# [INFO] readme.html already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/eclipse/ already added, skipping
# [INFO] org/eclipse/persistence/ already added, skipping
# [INFO] org/eclipse/persistence/internal/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] org/apache/ already added, skipping
# [INFO] org/apache/commons/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/NOTICE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/org.apache.commons/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/LICENSE.txt already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] com/google/common/ already added, skipping
# [INFO] com/google/common/util/ already added, skipping
# [INFO] com/google/common/util/concurrent/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/maven/com.google.guava/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] javax/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] org/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] META-INF/ already added, skipping
# [INFO] META-INF/MANIFEST.MF already added, skipping
# [INFO] com/ already added, skipping
# [INFO] com/google/ already added, skipping
# [INFO] META-INF/maven/ already added, skipping
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD SUCCESS
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  8.481 s
# [INFO] Finished at: 2020-04-23T06:38:09Z
# [INFO] ------------------------------------------------------------------------

# %%
#@timeout_decorator.timeout(30*60)
def run_java(jarfile, javafile):
    cmd=f"java -cp {jarfile} {javafile}"
    result =subprocess.run(cmd, universal_newlines = True, shell=True,stdout = subprocess.PIPE)
    print(result.stdout)
    return result

# ChainNonMarkovian 6 5 1 -1 0 CCALP 1234
def run_chain(model, N, exovarsize, target, obsvar, dovar, method, seed):
    
    if obsvar is None: obsvar = -1;
    elif obsvar<0: obsvar = N + obsvar;
    
    if dovar is None: dovar = -1;    
    elif dovar<0: dovar = N + dovar;
    
    if target is None: target = N//2;
    elif target<0: target = N + target;
    
    warmups = 2
    repetitions = 5
    
    javafile = f"{exp_folder}/RunExperiments.java {model} {N} {exovarsize} {target} {obsvar} {dovar} {method} {seed} {warmups} {repetitions} "  
    try:
        result = run_java(jarfile, javafile)
        output = [float(x) for x in result.stdout.splitlines()[-1].split(",")]
    except:
        output = [float("inf"),float("inf"),float("nan")]
        
    return output

def run_chain_markovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=0, method="CVE", seed=1234):    
    return run_chain("ChainMarkovian", N, exovarsize, target, obsvar, dovar, method, seed)

def run_chain_nonmarkovian(N=4, exovarsize=6, target=None, obsvar=-1, dovar=0, method="CVE", seed=1234):
    return run_chain("ChainNonMarkovian", N, exovarsize, target, obsvar, dovar, method, seed)

# %%
run_chain_markovian(N=5, method="CCVE")
# Out:
# ChainMarkovian
#    N=5 exovarsize=6 target=2 obsvar=4 dovar=0 method=CCVE seed=1234
# =================================================================
# Running experiments...
# set timeout 600 s.
# Warm-up #0 in 654.491 ms.
# set timeout 600 s.
# Warm-up #1 in 225.685 ms.
# set timeout 600 s.
# Warm-up #2 in 212.223 ms.
# set timeout 300 s.
# Measurement #0 in 186.655 ms. size=0.0
# set timeout 300 s.
# Measurement #1 in 147.717 ms. size=0.0
# set timeout 300 s.
# Measurement #2 in 147.918 ms. size=0.0
# set timeout 300 s.
# Measurement #3 in 141.027 ms. size=0.0
# set timeout 300 s.
# Measurement #4 in 142.577 ms. size=0.0
# set timeout 300 s.
# Measurement #5 in 148.234 ms. size=0.0
# set timeout 300 s.
# Measurement #6 in 121.02 ms. size=0.0
# set timeout 300 s.
# Measurement #7 in 145.196 ms. size=0.0
# set timeout 300 s.
# Measurement #8 in 135.793 ms. size=0.0
# set timeout 300 s.
# Measurement #9 in 131.235 ms. size=0.0
# 144.7372,25.482599999999998,0.0,0.9253716881664275,0.9253716881664275
# [144.7372, 25.482599999999998, 0.0, 0.9253716881664275, 0.9253716881664275]

# %%
run_chain_markovian(N=5, dovar=0, obsvar=None, target=-1, method="CCVE")
# Out:
# ChainMarkovian
#    N=5 exovarsize=6 target=4 obsvar=-1 dovar=0 method=CCVE seed=1234
# =================================================================
# Running experiments...
# set timeout 600 s.
# Warm-up #0 in 687.045 ms.
# set timeout 600 s.
# Warm-up #1 in 221.304 ms.
# set timeout 600 s.
# Warm-up #2 in 198.907 ms.
# set timeout 300 s.
# Measurement #0 in 179.154 ms. size=0.0
# set timeout 300 s.
# Measurement #1 in 147.668 ms. size=0.0
# set timeout 300 s.
# Measurement #2 in 156.331 ms. size=0.0
# set timeout 300 s.
# Measurement #3 in 139.578 ms. size=0.0
# set timeout 300 s.
# Measurement #4 in 131.719 ms. size=0.0
# set timeout 300 s.
# Measurement #5 in 141.814 ms. size=0.0
# set timeout 300 s.
# Measurement #6 in 119.471 ms. size=0.0
# set timeout 300 s.
# Measurement #7 in 135.192 ms. size=0.0
# set timeout 300 s.
# Measurement #8 in 130.146 ms. size=0.0
# set timeout 300 s.
# Measurement #9 in 130.507 ms. size=0.0
# 141.158,24.211599999999997,0.0,0.62254336,0.62254336
# [141.158, 24.211599999999997, 0.0, 0.62254336, 0.62254336]

# %%
def run_experiments(f, args, outkeys=("time", "query_time", "size", "lowerbound", "upperbound")):

    non_evaluable = []
                      
    def is_evaluable(args): 
        return not {k:v for (k,v) in args.items() if k not in ["N"]} in \
    [{k:v for (k,v) in a.items() if k not in ["N"]} for a in non_evaluable]
         
        
    result = pd.DataFrame(columns=list(args.keys())+list(outkeys))
    log_file = f"{log_folder}{strdate()}_{f.__name__}.txt"

    for v in itertools.product(*list(args.values())):
        
        argsv = dict(zip(list(args.keys()), v))
        
        strio = io.StringIO()
        with open(log_file, 'a+') as logger:
            with redirect_stdout(strio):
                if is_evaluable(argsv):
                    outvals = f(**argsv)
                    if np.isnan(outvals).any(): non_evaluable.append(argsv)
                else:
                    outvals=[float("nan")]*len(outkeys)
            logger.write(strio.getvalue())
        result = result.append({**argsv, **dict(zip(list(outkeys), outvals))}, ignore_index=True)
        print(dict(result.iloc[-1]))
    
    return result

# %%
SEED = [1234+i*1234 for i in range(10)]

# %%
# with evidence chain markovian 
args = {"N":list(range(5,15)),"dovar":[0], "exovarsize":[6,8,10], "obsvar":[-1],  "seed":SEED, "method":["CVE", "CCVE", "CCALPeps"]}
results1 = run_experiments(run_chain_markovian, args)
res_file = f"{res_folder}{strdate()}_chain_markovian_ev.csv"
results1.to_csv(res_file)
results1
# Out:
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 2.2115, 'query_time': 2.1892, 'size': 0.0, 'lowerbound': 0.9253716881664275, 'upperbound': 0.9253716881664275}
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 144.5468, 'query_time': 25.221799999999998, 'size': 0.0, 'lowerbound': 0.9253716881664275, 'upperbound': 0.9253716881664275}
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 960.2171000000001, 'query_time': 957.9493, 'size': 1.1102230246251565e-16, 'lowerbound': 0.9443987446020042, 'upperbound': 0.9443987446020042}
# {'N': 6, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 3.9719, 'query_time': 3.9506, 'size': 0.0, 'lowerbound': 0.9511876167902436, 'upperbound': 0.9511876167902436}
# {'N': 6, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 251.5618, 'query_time': 115.9944, 'size': 0.0, 'lowerbound': 0.9511876167902436, 'upperbound': 0.9511876167902436}
# {'N': 6, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 1408.5001, 'query_time': 1405.8165000000001, 'size': 8.881784197001253e-17, 'lowerbound': 0.9477339244571394, 'upperbound': 0.9477339244571397}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 12.2246, 'query_time': 12.2039, 'size': 0.0, 'lowerbound': 0.9510878019665394, 'upperbound': 0.9510878019665394}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 637.9259, 'query_time': 506.9581, 'size': 0.0, 'lowerbound': 0.9510878019665394, 'upperbound': 0.9510878019665394}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 1829.3033, 'query_time': 1826.1001, 'size': 1.1102230246251565e-16, 'lowerbound': 0.9477339244571394, 'upperbound': 0.9477339244571397}
# {'N': 8, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 52.8645, 'query_time': 52.840700000000005, 'size': 0.0, 'lowerbound': 0.6249724220834801, 'upperbound': 0.6249724220834801}
# {'N': 8, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 3402.6168, 'query_time': 3242.9491000000003, 'size': 0.0, 'lowerbound': 0.62497242208348, 'upperbound': 0.62497242208348}
# {'N': 9, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 17748.3854, 'query_time': 17551.618300000002, 'size': 0.0, 'lowerbound': 0.3410358799660232, 'upperbound': 0.3410358799660232}
# {'N': 9, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 2639.4525000000003, 'query_time': 2636.1803, 'size': 5.828670879282072e-16, 'lowerbound': 0.34702525795402045, 'upperbound': 0.34702525795402106}
# {'N': 10, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 1542.5520000000001, 'query_time': 1542.5149, 'size': 0.0, 'lowerbound': 0.04379213235825061, 'upperbound': 0.04379213235825061}
# {'N': 10, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 87033.6546, 'query_time': 86827.10429999999, 'size': 0.0, 'lowerbound': 0.04379213235825064, 'upperbound': 0.04379213235825064}
# {'N': 10, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 2944.1832000000004, 'query_time': 2940.4285, 'size': 6.938893903907228e-17, 'lowerbound': 0.04367803471558617, 'upperbound': 0.04367803471558625}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 10967.8022, 'query_time': 10967.7588, 'size': 0.0, 'lowerbound': 0.8084042791684029, 'upperbound': 0.8084042791684029}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 3241.184, 'query_time': 3237.6428, 'size': 3.4416913763379854e-16, 'lowerbound': 0.8085187344720746, 'upperbound': 0.8085187344720749}
# {'N': 12, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': nan, 'query_time': nan, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 12, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 12, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 4039.1953999999996, 'query_time': 4034.7153, 'size': 5.551115123125783e-16, 'lowerbound': 0.3804351908799203, 'upperbound': 0.3804351908799209}
# {'N': 13, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': nan, 'query_time': nan, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 13, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 13, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 4210.039, 'query_time': 4205.9083, 'size': 6.938893903907228e-16, 'lowerbound': 0.34580228452009076, 'upperbound': 0.34580228452009143}
# {'N': 14, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': nan, 'query_time': nan, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 14, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': inf, 'query_time': inf, 'size': nan, 'lowerbound': nan, 'upperbound': nan}
# {'N': 14, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 4224.2923, 'query_time': 4220.1104, 'size': 3.3306690738754696e-16, 'lowerbound': 0.8488770966383006, 'upperbound': 0.848877096638301}
#      N dovar obsvar  seed    method        time  query_time          size  \
# 0    5     0     -1  1234       CVE      2.2115      2.1892  0.000000e+00
# 1    5     0     -1  1234      CCVE    144.5468     25.2218  0.000000e+00
# 2    5     0     -1  1234  CCALPeps    960.2171    957.9493  1.110223e-16
# 3    6     0     -1  1234       CVE      3.9719      3.9506  0.000000e+00
# 4    6     0     -1  1234      CCVE    251.5618    115.9944  0.000000e+00
# 5    6     0     -1  1234  CCALPeps   1408.5001   1405.8165  8.881784e-17
# 6    7     0     -1  1234       CVE     12.2246     12.2039  0.000000e+00
# 7    7     0     -1  1234      CCVE    637.9259    506.9581  0.000000e+00
# 8    7     0     -1  1234  CCALPeps   1829.3033   1826.1001  1.110223e-16
# 9    8     0     -1  1234       CVE     52.8645     52.8407  0.000000e+00
# 10   8     0     -1  1234      CCVE   3402.6168   3242.9491  0.000000e+00
# 11   8     0     -1  1234  CCALPeps   2275.6809   2272.4286  7.438494e-16
# 12   9     0     -1  1234       CVE    252.4128    252.3894  0.000000e+00
# 13   9     0     -1  1234      CCVE  17748.3854  17551.6183  0.000000e+00
# 14   9     0     -1  1234  CCALPeps   2639.4525   2636.1803  5.828671e-16
# 15  10     0     -1  1234       CVE   1542.5520   1542.5149  0.000000e+00
# 16  10     0     -1  1234      CCVE  87033.6546  86827.1043  0.000000e+00
# 17  10     0     -1  1234  CCALPeps   2944.1832   2940.4285  6.938894e-17
# 18  11     0     -1  1234       CVE  10967.8022  10967.7588  0.000000e+00
# 19  11     0     -1  1234      CCVE         inf         inf           NaN
# 20  11     0     -1  1234  CCALPeps   3241.1840   3237.6428  3.441691e-16
# 21  12     0     -1  1234       CVE         NaN         NaN           NaN
# 22  12     0     -1  1234      CCVE         inf         inf           NaN
# 23  12     0     -1  1234  CCALPeps   4039.1954   4034.7153  5.551115e-16
# 24  13     0     -1  1234       CVE         NaN         NaN           NaN
# 25  13     0     -1  1234      CCVE         inf         inf           NaN
# 26  13     0     -1  1234  CCALPeps   4210.0390   4205.9083  6.938894e-16
# 27  14     0     -1  1234       CVE         NaN         NaN           NaN
# 28  14     0     -1  1234      CCVE         inf         inf           NaN
# 29  14     0     -1  1234  CCALPeps   4224.2923   4220.1104  3.330669e-16
#
#     lowerbound  upperbound
# 0     0.925372    0.925372
# 1     0.925372    0.925372
# 2     0.944399    0.944399
# 3     0.951188    0.951188
# 4     0.951188    0.951188
# 5     0.947734    0.947734
# 6     0.951088    0.951088
# 7     0.951088    0.951088
# 8     0.947734    0.947734
# 9     0.624972    0.624972
# 10    0.624972    0.624972
# 11    0.622544    0.622544
# 12    0.341036    0.341036
# 13    0.341036    0.341036
# 14    0.347025    0.347025
# 15    0.043792    0.043792
# 16    0.043792    0.043792
# 17    0.043678    0.043678
# 18    0.808404    0.808404
# 19         NaN         NaN
# 20    0.808519    0.808519
# 21         NaN         NaN
# 22         NaN         NaN
# 23    0.380435    0.380435
# 24         NaN         NaN
# 25         NaN         NaN
# 26    0.345802    0.345802
# 27         NaN         NaN
# 28         NaN         NaN
# 29    0.848877    0.848877

# %%
# with evidence chain non markovian
args = {"N":list(range(5,30,2)), "dovar":[0], "exovarsize":[6,8,10], "obsvar":[-1], "seed":SEED, "method":["CVE", "CCVE", "CCALPeps"]}
results2 = run_experiments(run_chain_nonmarkovian, args)
res_file = f"{res_folder}{strdate()}_chain_nonmarkovian_ev.csv"
results2.to_csv(res_file)
results2
# Out:
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 1.8293, 'query_time': 1.807, 'size': 0.0, 'lowerbound': 0.7909377756936551, 'upperbound': 0.7909377756936551}
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 82.03150000000001, 'query_time': 7.945600000000001, 'size': 0.0, 'lowerbound': 0.7909377756936552, 'upperbound': 0.7909377756936552}
# {'N': 5, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 751.4406, 'query_time': 748.9181, 'size': 4.0498719822146255e-09, 'lowerbound': 0.7654994225007514, 'upperbound': 0.7654994265506234}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 2.6026, 'query_time': 2.5793, 'size': 0.0, 'lowerbound': 0.037857448281030284, 'upperbound': 0.037857448281030284}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 115.03519999999999, 'query_time': 20.7963, 'size': 0.0, 'lowerbound': 0.037857448281030284, 'upperbound': 0.037857448281030284}
# {'N': 7, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 1260.7854, 'query_time': 1258.0397, 'size': 6.748455201155413e-07, 'lowerbound': 0.05650111964923242, 'upperbound': 0.056501794494752546}
# {'N': 9, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 5.039199999999999, 'query_time': 5.0166, 'size': 0.0, 'lowerbound': 0.6291273067323413, 'upperbound': 0.6291273067323413}
# {'N': 9, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 205.3702, 'query_time': 96.75559999999999, 'size': 0.0, 'lowerbound': 0.6291273067323413, 'upperbound': 0.6291273067323413}
# {'N': 9, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 2204.4863, 'query_time': 2201.3301, 'size': 2.4663995237261813e-07, 'lowerbound': 0.6290940778485274, 'upperbound': 0.6290943244884798}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 13.672300000000002, 'query_time': 13.652700000000001, 'size': 0.0, 'lowerbound': 0.11468758341717825, 'upperbound': 0.11468758341717825}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCVE', 'time': 471.1253, 'query_time': 361.9228, 'size': 0.0, 'lowerbound': 0.1146875834171783, 'upperbound': 0.1146875834171783}
# {'N': 11, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CCALPeps', 'time': 2179.8892, 'query_time': 2176.5652999999998, 'size': 8.99977301557775e-08, 'lowerbound': 0.12000068000047992, 'upperbound': 0.12000076999821008}
# {'N': 13, 'dovar': 0, 'obsvar': -1, 'seed': 1234, 'method': 'CVE', 'time': 57.262800000000006, 'query_time': 57.2374, 'size': 0.0, 'lowerbound': 0.42714177008688914, 'upperbound': 0.42714177008688914}

# %%
# without evidence chain markovian 
#args = {"N":list(range(5,15)), "dovar":[0], "target":[-1], "obsvar":[None], "seed":[1234], "method":["CVE", "CCVE", "CCALP", "CCALPeps"]}
#results3 = run_experiments(run_chain_markovian, args)
#res_file = f"{res_folder}{strdate()}_chain_markovian_nonev.csv"
#results3.to_csv(res_file)
#results3

# %%
# without evidence chain non markovian
#args = {"N":list(range(5,30,2)), "dovar":[0], "target":[-1], "obsvar":[None], "seed":[1234], "method":["CVE", "CCVE", "CCALP", "CCALPeps"]}
#results4 = run_experiments(run_chain_nonmarkovian, args)
#res_file = f"{res_folder}{strdate()}_chain_nonmarkovian_nonev.csv"
#results4.to_csv(res_file)
#results4

# %%
methods = np.unique(results1["method"].to_numpy())

# %%
results1.filter(items=["N","method","time"])

# %%
fig=plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')

N = np.unique(results1["N"].to_numpy())

for m in methods:
    #if m not in ["CCVE"]:
        data = results1.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
        plt.plot(N, data, marker='o', label=m)
        plt.legend()
        #ax1.set_yscale('log')
        
plt.ylabel("time (ms)")
plt.xlabel("Number of endogenous variables")

plt.title("Chain (Makovian case)")

plt.show()

# %%
fig=plt.figure(figsize=(10, 8), dpi= 80, facecolor='w', edgecolor='k')

N = np.unique(results2["N"].to_numpy())


for m in methods:
    #if m not in ["CCVE"]:

        data = results2.query(f"method=='{m}'").filter(items=["time"]).to_numpy()
        plt.plot(N, data, marker='o', label=m)

        #data = results2.query(f"method=='{m}'").filter(items=["query_time"]).to_numpy()
        #ax2.plot(N, data, marker='o', label=m)
        #ax1.set_yscale('log')

        plt.legend()   
        
plt.ylabel("time (ms)")
plt.title("Chain (Non-Makovian case)")
plt.xlabel("Number of endogenous variables")

fig.show()
